# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
file_path = '201908-citibike-tripdata.csv'
df = pd.read_csv(file_path)

# %%
df.sample(5)
# Out:
#          tripduration                 starttime                  stoptime  \
# 184494           1059  2019-08-03 10:36:28.2960  2019-08-03 10:54:08.1720
# 1345157           278  2019-08-18 13:01:22.3730  2019-08-18 13:06:01.3300
# 263948            423  2019-08-04 12:08:26.9160  2019-08-04 12:15:29.9980
# 682190            424  2019-08-09 20:16:53.4010  2019-08-09 20:23:57.6950
# 1234690           371  2019-08-16 19:45:38.7460  2019-08-16 19:51:50.6390
#
#          start station id       start station name  start station latitude  \
# 184494             3396.0     Clinton St & 4 Place               40.678356
# 1345157            3119.0     Vernon Blvd & 50 Ave               40.742327
# 263948             3306.0            10 St & 7 Ave               40.666208
# 682190              382.0  University Pl & E 14 St               40.734927
# 1234690             519.0    Pershing Square North               40.751873
#
#          start station longitude  end station id  \
# 184494                -74.000145           274.0
# 1345157               -73.954117          3125.0
# 263948                -73.981999          3416.0
# 682190                -73.992005           394.0
# 1234690               -73.977706           474.0
#
#                        end station name  end station latitude  \
# 184494   Lafayette Ave & Fort Greene Pl             40.686919
# 1345157                   45 Rd & 11 St             40.747086
# 263948                  7 Ave & Park Pl             40.677615
# 682190                E 9 St & Avenue C             40.725213
# 1234690                 5 Ave & E 29 St             40.745168
#
#          end station longitude  bikeid    usertype  birth year  gender
# 184494              -73.976682   34111  Subscriber        1989       0
# 1345157             -73.949772   19738  Subscriber        1993       2
# 263948              -73.973243   35594  Subscriber        1989       1
# 682190              -73.977688   30422  Subscriber        1996       1
# 1234690             -73.986831   29430  Subscriber        1967       1

# %%
# 2. Check the datatypes of your columns. 
df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
df['tripduration'] = pd.to_datetime(df['tripduration'], unit='s')
df.sample(5)
# Out:
#                tripduration                 starttime  \
# 2052736 1970-01-01 00:19:42  2019-08-27 22:30:47.8820
# 1945547 1970-01-01 00:18:04  2019-08-26 17:48:37.5580
# 1463275 1970-01-01 00:15:02  2019-08-20 08:03:22.4550
# 1837467 1970-01-01 00:16:36  2019-08-25 11:54:50.9630
# 1869310 1970-01-01 00:11:10  2019-08-25 17:09:36.6070
#
#                          stoptime  start station id  \
# 2052736  2019-08-27 22:50:30.0330            3699.0
# 1945547  2019-08-26 18:06:42.4930            3467.0
# 1463275  2019-08-20 08:18:25.1620             251.0
# 1837467  2019-08-25 12:11:27.7980             355.0
# 1869310  2019-08-25 17:20:47.4530            3686.0
#
#                  start station name  start station latitude  \
# 2052736             W 50 St & 9 Ave               40.763605
# 1945547  W Broadway & Spring Street               40.724947
# 1463275         Mott St & Prince St               40.723180
# 1837467       Bayard St & Baxter St               40.716021
# 1869310   Gansevoort St & Hudson St               40.739448
#
#          start station longitude  end station id    end station name  \
# 2052736               -73.989180          3699.0     W 50 St & 9 Ave
# 1945547               -74.001659           478.0    11 Ave & W 41 St
# 1463275               -73.994800           492.0     W 33 St & 7 Ave
# 1837467               -73.999744           380.0    W 4 St & 7 Ave S
# 1869310               -74.005070           285.0  Broadway & E 14 St
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 2052736             40.763605             -73.989180   32325  Subscriber
# 1945547             40.760301             -73.998842   35126  Subscriber
# 1463275             40.750200             -73.990931   15350  Subscriber
# 1837467             40.734011             -74.002939   31581  Subscriber
# 1869310             40.734546             -73.990741   35334  Subscriber
#
#          birth year  gender
# 2052736        1990       1
# 1945547        1993       1
# 1463275        1960       1
# 1837467        1995       1
# 1869310        1985       1

# %%
# 4. Check the datatypes of your columns. 
df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
df.to_csv('2019-08-citibike-tripdata_tripdur_adjusted.csv', index=False)
